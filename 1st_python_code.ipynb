# %%
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings ('ignore')

# %matplotlib inline
sns.set_style('darkgrid')
#sns.set_style('white')
plt.rcParams['figure.figsize']=10,6


movies=pd.read_csv('C:\\Users\\735184\\Downloads\\P4-Movie-Ratings.csv')

movies.columns=['Film','Genre','Critrc_Ratings_prctg', 'Aud_Ratings_prctg','Budget_mln_DLR', 'Year_Release']
movies.Film=movies.Film.astype('category')
movies.Genre=movies.Genre.astype('category')
movies.Year_Release=movies.Year_Release.astype('category')

hist_lst=[]
label_lst=[]
for mov_typ in movies.Genre.unique():
    label_lst.append(mov_typ)
    hist_lst.append(movies[movies.Genre== mov_typ].Budget_mln_DLR)
    
plt.hist(hist_lst,bins=30,stacked=True,label=label_lst)  #for all movie type bins=15 
plt.legend(loc='upper center', bbox_to_anchor=(1.1,1))
#plt.show()

# %%
x=sns.FacetGrid(movies,row='Genre',col='Year_Release',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='Black')
x=x.map(plt.scatter,'Critrc_Ratings_prctg','Aud_Ratings_prctg',**kws)
for ax in x.axes.flat:
    ax.plot((0,100),(0,100),c='Gray',ls='--')
x.add_legend()

# %%
plt.hist(lst,bins=30,stacked=True,rwidth=1) 
plt.show()

# %%
for mov_typ in movies.Genre.unique():
    
    plt.hist(movies[movies.Genre== mov_typ].Budget_mln_DLR,bins=15,stacked=True)

plt.show()

# %%
plt.hist([ movies[movies.Genre=='Action'].Budget_mln_DLR, \
           movies[movies.Genre=='Drama'].Budget_mln_DLR, \
           movies[movies.Genre=='Thriller'].Budget_mln_DLR],bins=15,stacked=True)
plt.show()

# %%
# Out:
# [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]
# Categories (7, object): [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]

# %%
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
# Out:
#        Critrc_Ratings_prctg  Aud_Ratings_prctg  Budget_mln_DLR
# count            559.000000         559.000000      559.000000
# mean              47.309481          58.744186       50.236136
# std               26.413091          16.826887       48.731817
# min                0.000000           0.000000        0.000000
# 25%               25.000000          47.000000       20.000000
# 50%               46.000000          58.000000       35.000000
# 75%               70.000000          72.000000       65.000000
# max               97.000000          96.000000      300.000000

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film                    559 non-null category
# Genre                   559 non-null category
# Critrc_Ratings_prctg    559 non-null int64
# Aud_Ratings_prctg       559 non-null int64
# Budget_mln_DLR          559 non-null int64
# Year_Release            559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
# Out:
#                                    Film      Genre  RotnTom_Ratings_perctg  \
# 0                 (500) Days of Summer      Comedy                      87
# 1                           10,000 B.C.  Adventure                       9
# 2                            12 Rounds      Action                      30
# 3                             127 Hours  Adventure                      93
# 4                             17 Again      Comedy                      55
# 5                                  2012     Action                      39
# 6                            27 Dresses     Comedy                      40
# 7                      30 Days of Night     Horror                      50
# 8                    30 Minutes or Less     Comedy                      43
# 9                                 50/50     Comedy                      93
# 10                           88 Minutes      Drama                       5
# ...

# %%
data.columns=[Film','Genre','Rotten_Tomatoes_Ratings_perctg', 'Audience Ratings_perctg','Budget_million_DLR', 'Year of release']
# Out:
#   File "<ipython-input-4-e62e18064bb8>", line 1
#     data.columns=[Film','Genre','Rotten_Tomatoes_Ratings_perctg', 'Audience Ratings_perctg','Budget_million_DLR', 'Year of release']
#                         ^
# SyntaxError: invalid syntax

# %%
yr[year[2018]]
# Out:
# 2018

# %%
profit[year[2020]]
# Out:
# array([2250,  140,  230,  320,  410,  500,  630,  720,  810, 1120, 2441,
#        1710])

# %%
profit_after_tax
# Out:
# array([[  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
#        [  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
#        [  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
#        [  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
#        [  66.5,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  780.5,  927.5, 1197. ],
#        [  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
#        [  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
#        [  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
# ...

# %%
# Out:
# 70

# %%
# Out:
# array([[ 100,  200,  300,  400,  500,  600,  700,  800,  900, 1200, 1400,
#         1800],
#        [ 500,  600,  700,  800,  900, 1000,  700,  800,  900,  850,  750,
#          900],
#        [ 750,  850,  950, 1000,  990,  780,  960,  550,  680,  780,  890,
#         1000]])

# %%
# Out:
# 'MAY'

# %%
share_price
# Out:
# array([['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUNE', 'JULY', 'AUG', 'SEPT',
#         'OCT', 'NOV', 'DEC'],
#        ['100', '200', '300', '400', '500', '600', '700', '800', '900',
#         '1200', '1400', '1800'],
#        ['500', '600', '700', '800', '900', '1000', '700', '800', '900',
#         '850', '750', '900'],
#        ['750', '850', '950', '1000', '990', '780', '960', '550', '680',
#         '780', '890', '1000']], dtype='<U4')

# %%
share_price[2,2]
# Out:
# '700'

# %%
# Out:
# 0.8635975045753573
