# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
mon=[]
yr=[]
dict_month={'JAN':0,'FEB':1,'MAR':2,'APR':3,'MAY':4,'JUNE':5,'JULY':6,'AUG':7,'SEPT':8,'OCT':9,'NOV':10,'DEC':11}
for key in dict_month:
    mon.append(key)
dict_year={2011:0,2012:1,2013:2,2014:3,2015:4,2016:5,2017:6,2018:7,2019:8,2020:9}
for key in dict_year:
    yr.append(key)
rvn_tcs_11=[200,400,1400,1330,1500,990,700,800,2100,1200,1450,1600]
rvn_tcs_12=[2000,1200,700,900,1500,1600,500,1800,1900,1200,1299,1900]
rvn_tcs_13=[2100,300,1300,1400,1500,900,1700,200,700,1200,1034,1200]
rvn_tcs_14=[2100,1900,1300,1200,900,1800,1700,700,900,1200,2400,1000]
rvn_tcs_15=[1100,750,300,400,500,600,700,800,900,1200,900,1887]
rvn_tcs_16=[2300,150,1300,2400,1500,1600,900,1200,900,1200,2400,1345]
rvn_tcs_17=[440,2200,1300,1400,1900,1690,490,2100,1990,1200,2100,2870]
rvn_tcs_18=[1900,700,1900,2400,650,1800,1700,800,1900,900,1900,2100]
rvn_tcs_19=[1200,1800,500,700,1900,1600,950,1870,2100,1299,1450,2480]
rvn_tcs_20=[2300,980,780,1100,2100,2600,1270,2800,1900,1100,2540,1800]
exp_tcs_11=[200,60,70,1330,90,100,70,80,90,1200,70,90]
exp_tcs_12=[50,60,70,80,90,100,70,80,90,80,70,90]
exp_tcs_13=[50,60,70,80,90,100,70,80,90,80,70,90]
exp_tcs_14=[50,60,70,80,90,100,70,80,90,80,70,90]
exp_tcs_15=[5,60,70,80,90,100,70,80,90,85,75,90]
exp_tcs_16=[50,60,70,80,90,100,70,80,90,80,70,90]
exp_tcs_17=[50,60,70,80,90,100,70,80,90,80,70,90]
exp_tcs_18=[50,60,70,80,90,100,70,80,90,80,70,90]
exp_tcs_19=[50,60,70,80,90,100,70,80,90,80,70,90]
exp_tcs_20=[50,60,70,80,90,100,70,80,90,80,99,90]
shr_inf_11=[750,850,950,100,990,780,96,550,680,780,890,1000]
shr_inf_12=[750,850,950,1000,990,780,960,550,680,780,890,1000]
shr_inf_13=[750,850,950,1000,990,780,960,550,680,780,890,1000]
shr_inf_14=[750,850,950,1000,990,780,960,550,680,780,890,1000]
shr_inf_15=[750,850,950,1000,990,780,960,550,680,780,890,1000]
shr_inf_16=[750,850,950,1000,990,780,960,550,680,780,890,1000]
shr_inf_17=[750,850,950,1000,990,780,960,550,680,780,890,1000]
shr_inf_18=[750,850,950,1000,990,780,960,550,680,780,890,1000]
shr_inf_19=[750,850,950,1000,990,780,960,550,680,780,890,1000]
shr_inf_20=[750,850,950,1000,990,780,960,550,680,780,890,1000]

rvn_price_TCS=np.array([rvn_tcs_11,rvn_tcs_12,rvn_tcs_13,rvn_tcs_14,rvn_tcs_15,rvn_tcs_16,rvn_tcs_17,rvn_tcs_18,rvn_tcs_19,rvn_tcs_20])
exp_price_TCS=np.array([exp_tcs_11,exp_tcs_12,exp_tcs_13,exp_tcs_14,exp_tcs_15,exp_tcs_16,exp_tcs_17,exp_tcs_18,exp_tcs_19,exp_tcs_20])
share_price_inf=np.array([shr_inf_11,shr_inf_12,shr_inf_13,shr_inf_14,shr_inf_15,shr_inf_16,shr_inf_17,shr_inf_18,shr_inf_19,shr_inf_20])

profit=rvn_price_TCS-exp_price_TCS
profit_after_tax=(rvn_price_TCS-exp_price_TCS)-(rvn_price_TCS-exp_price_TCS)*0.30
Profit_perc=(profit_after_tax/profit)*100

# %matplotlib inline
plt.rcParams['figure.figsize']= 12,8
'''
fig = plt.figure() 
ax1 = fig.add_subplot(221) 
ax2 = fig.add_subplot(222) 
ax3 = fig.add_subplot(223) 
ax4 = fig.add_subplot(224) 
'''

def mygraph(anarray,yearlist=yr):
    colour={2011:'Magenta',2012:'Blue',2013:'Brown',2014:'Pink',2015:'Violet',2016:'Green',2017:'Orange',2018:'Maroon',2019:'Black',2020:'Red'}
    lin_sty={2011:'--',2012:'--',2013:'-.',2014:'--',2015:':',2016:'-.',2017:'--',2018:':',2019:'-.',2020:'-'}
    marker_sty={2011:'s',2012:'^',2013:'D',2014:'x',2015:'o',2016:'s',2017:'^',2018:'D',2019:'o',2020:'H'}
    latest_yr=max(yearlist)
    plt.xlim([0,12])
    plt.ylim([0, max(range(0,3300,300))])
    for i in  yearlist:
        if i==latest_yr:
            plt.plot(anarray[dict_year[i]],c=colour[i],ls=lin_sty[i],marker=marker_sty[i],ms=12,label=i)
        else:
            plt.plot(anarray[dict_year[i]],c=colour[i],ls=lin_sty[i],marker=marker_sty[i],ms=7,label=i)
    plt.xticks(list(range(0,12)),mon,rotation='vertical')
    #plt.yticks(list(range(0,3000,200)))
    plt.legend(loc='upper left',bbox_to_anchor=(1,1))
    plt.show()
        
mygraph(profit,yr)     
mygraph(profit_after_tax,yr)

# %%
Profit_perc
# Out:
# array([[nan, 70., 70., nan, 70., 70., 70., 70., 70., nan, 70., 70.],
#        [70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70.],
#        [70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70.],
#        [70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70.],
#        [70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70.],
#        [70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70.],
#        [70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70.],
#        [70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70.],
#        [70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70.],
#        [70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70., 70.]])

# %%
yr[year[2018]]
# Out:
# 2018

# %%
profit[year[2020]]
# Out:
# array([2250,  140,  230,  320,  410,  500,  630,  720,  810, 1120, 2441,
#        1710])

# %%
profit_after_tax
# Out:
# array([[  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
#        [  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
#        [  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
#        [  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
#        [  66.5,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  780.5,  927.5, 1197. ],
#        [  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
#        [  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
#        [  35. ,   98. ,  161. ,  224. ,  287. ,  350. ,  441. ,  504. ,
#          567. ,  784. ,  931. , 1197. ],
# ...

# %%
# Out:
# 70

# %%
# Out:
# array([[ 100,  200,  300,  400,  500,  600,  700,  800,  900, 1200, 1400,
#         1800],
#        [ 500,  600,  700,  800,  900, 1000,  700,  800,  900,  850,  750,
#          900],
#        [ 750,  850,  950, 1000,  990,  780,  960,  550,  680,  780,  890,
#         1000]])

# %%
# Out:
# 'MAY'

# %%
share_price
# Out:
# array([['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUNE', 'JULY', 'AUG', 'SEPT',
#         'OCT', 'NOV', 'DEC'],
#        ['100', '200', '300', '400', '500', '600', '700', '800', '900',
#         '1200', '1400', '1800'],
#        ['500', '600', '700', '800', '900', '1000', '700', '800', '900',
#         '850', '750', '900'],
#        ['750', '850', '950', '1000', '990', '780', '960', '550', '680',
#         '780', '890', '1000']], dtype='<U4')

# %%
share_price[2,2]
# Out:
# '700'

# %%
# Out:
# 0.8635975045753573
