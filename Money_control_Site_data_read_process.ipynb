# %%
import re
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import warnings
warnings.filterwarnings('ignore')

url="https://www.moneycontrol.com/stocks/marketstats/nsegainer/index.php"

tab_lst=pd.io.html.read_html(url)

#TAB_TOP_GAIN
TAB_TOP_GAIN=tab_lst[0]
TAB_TOP_GAIN=TAB_TOP_GAIN.dropna(thresh=3)
TAB_TOP_GAIN=TAB_TOP_GAIN.drop(['Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12','Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
       'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
       'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
       'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
       'Unnamed: 29', 'Unnamed: 30'], axis=1)
TAB_TOP_GAIN=TAB_TOP_GAIN.drop(['% Gain','5 Day Performance  5 Day Performance  Volume  Lower Circuit  Upper Circuit  VWAP  SMA 30 DMA  50 DMA  150 DMA  200 DMA  Deliverables  P/E  P/B'], axis=1)
TAB_TOP_GAIN.columns=['Company_Name', 'High', 'Low', 'Last_Price', 'Prev_Close', 'Change']
TAB_TOP_GAIN=TAB_TOP_GAIN.drop_duplicates()
for i in TAB_TOP_GAIN.Company_Name.index:
    TAB_TOP_GAIN.Company_Name[i]=re.sub(r'Add.+','',TAB_TOP_GAIN.Company_Name[i])

a
# Out:
#         Company_Name      High       Low  Last_Price  Prev_Close  Change
# 0   Bharti Infratel     173.50    156.60      172.90      160.90   12.00
# 7     IndusInd Bank     454.70    415.50      449.15      425.50   23.65
# 14      Adani Ports     284.50    268.45      283.05      270.15   12.90
# 21    Tech Mahindra     525.85    506.35      521.20      506.85   14.35
# 28              M&M     403.45    385.10      397.80      387.15   10.65
# 35        JSW Steel     170.95    162.50      170.00      165.80    4.20
# 42         Reliance    1497.50   1445.00     1492.85     1460.75   32.10
# 49        Axis Bank     400.80    382.70      394.85      388.85    6.00
# 56    Eicher Motors   14074.95  13712.90    14015.00    13859.95  155.05
# 63   Dr Reddys Labs    3936.55   3870.30     3886.05     3852.50   33.55
# 70          Infosys     674.35    665.55      669.15      665.90    3.25
# 77           Grasim     491.95    476.40      484.00      482.40    1.60
# ...

# %%
'''
a=a.dropna()
a=a.drop(['Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12','Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
       'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
       'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
       'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
       'Unnamed: 29', 'Unnamed: 30'])
a=a.drop(['% Gain','5 Day Performance  5 Day Performance  Volume  Lower Circuit  Upper Circuit  VWAP  SMA 30 DMA  50 DMA  150 DMA  200 DMA  Deliverables  P/E  P/B'], axis=1)
a.columns=['Company_Name', 'High', 'Low', 'Last_Price', 'Prev_Close', 'Change']

a

#a=pd.concat([a,a])
#a=a.drop_duplicates()
for i in a.Company_Name.index:
    a.Company_Name[i]=re.sub(r'Add.+','',a.Company_Name[i])
#a            
'''
# Out:
#                                           Company Name         High      Low  \
# 0    Bharti Infratel Add to  Watchlist | Portfolio ...       173.20   156.60
# 1                                                5-Day   8784613.80      NaN
# 2                                               10-Day    277264.40      NaN
# 3                                               30-Day   7688107.13      NaN
# 4                                                3-Day       13.73%      NaN
# 5                                                5-Day       18.01%      NaN
# 6                                                8-Day       19.62%      NaN
# 7    IndusInd Bank Add to  Watchlist | Portfolio NE...       454.70   415.50
# 8                                                5-Day  25437313.00      NaN
# 9                                               10-Day          NaN      NaN
# 10                                              30-Day  30928085.63      NaN
# ...

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                          Company_Name    High     Low  \
# 0   Bharti Infratel Add to  Watchlist | Portfolio ...  171.90  156.60
# 77  Cipla Add to  Watchlist | Portfolio ACTIONS  P...  601.80  592.05
#
#     Last_Price  Prev_Close  Change
# 0       171.15      160.90   10.25
# 77      593.65      591.75    1.90

# %%
# Out:
#                                          Company_Name    High     Low  \
# 0   Bharti Infratel Add to  Watchlist | Portfolio ...  171.90  156.60
# 77  Cipla Add to  Watchlist | Portfolio ACTIONS  P...  601.80  592.05
#
#     Last_Price  Prev_Close  Change
# 0        170.1      160.90    9.20
# 77       594.0      591.75    2.25

# %%
# Out:
# array(['Bharti Infratel Add to  Watchlist | Portfolio ACTIONS  Only Buyers in Bharti Infratel on NSE',
#        'Cipla Add to  Watchlist | Portfolio ACTIONS  Pharma companies that can benefit from the demand for complex respiratory drugs'],
#       dtype=object)

# %%
#grp1=a.groupby(['Company_Name']).mean()
#grp1
#a=np.where(a.Company_Name,re.sub(r'\|.+','',a.Company_Name),a.Company_Name)
aa=np.unique(a.Company_Name.index)
counter=0
for s in a.Company_Name:
    
    a.Company_Name=re.sub(r'Add to Watchlist.+','',s)
    counter +=1
    
a
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#                                          Company_Name     High      Low  \
# 7   Bajaj Finserv Add to  Watchlist | Portfolio AC...   171.90   156.60
# 77  Bajaj Finserv Add to  Watchlist | Portfolio AC...   601.80   592.05
# 98  Bajaj Finserv Add to  Watchlist | Portfolio AC...  4796.00  4640.00
# 7   Bajaj Finserv Add to  Watchlist | Portfolio AC...   171.90   156.60
# 77  Bajaj Finserv Add to  Watchlist | Portfolio AC...   601.80   592.05
# 98  Bajaj Finserv Add to  Watchlist | Portfolio AC...  4796.00  4640.00
#
#     Last_Price  Prev_Close  Change
# 7       170.75      160.90    9.85
# 77      594.35      591.75    2.60
# 98     4693.15     4692.90    0.25
# ...

# %%
ar1=np.array[a.Company_Name.index]

ar1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-299596c1dc0d> in <module>()
# ----> 1 ar1=np.array[a.Company_Name.index]
#       2
#       3 ar1
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
a
# Out:
#                                          Company_Name    High     Low  \
# 0   Bharti Infratel Add to  Watchlist | Portfolio ...  171.90  156.60
# 77  Cipla Add to  Watchlist | Portfolio ACTIONS  P...  601.80  592.05
# 0   Bharti Infratel Add to  Watchlist | Portfolio ...  171.90  156.60
# 77  Cipla Add to  Watchlist | Portfolio ACTIONS  P...  601.80  592.05
#
#     Last_Price  Prev_Close  Change
# 0       170.50      160.90     9.6
# 77      593.75      591.75     2.0
# 0       170.50      160.90     9.6
# 77      593.75      591.75     2.0

# %%
a
# Out:
#                          Company_Name     High      Low  Last_Price  \
# 0   Bharti Infratel Add to Watchlist    171.90   156.60       171.1
# 77  Bharti Infratel Add to Watchlist   4796.00  4640.00      4728.0
# 98  Bharti Infratel Add to Watchlist    601.80   592.05       594.8
# 0   Bharti Infratel Add to Watchlist    171.90   156.60       171.1
# 77  Bharti Infratel Add to Watchlist   4796.00  4640.00      4728.0
# 98  Bharti Infratel Add to Watchlist    601.80   592.05       594.8
#
#     Prev_Close  Change
# 0       160.90   10.20
# 77     4692.90   35.10
# 98      591.75    3.05
# 0       160.90   10.20
# 77     4692.90   35.10
# 98      591.75    3.05

# %%
# Out:
#                                           Company Name     High      Low  \
# 0    Bharti Infratel Add to  Watchlist | Portfolio ...   171.90   156.60
# 84   Bajaj Finserv Add to  Watchlist | Portfolio AC...  4796.00  4640.00
# 105  Cipla Add to  Watchlist | Portfolio ACTIONS  P...   601.80   592.05
#
#      Last Price  Prev Close  Change  % Gain  \
# 0        169.20      160.90    8.30    5.16
# 84      4714.95     4692.90   22.05    0.47
# 105      594.05      591.75    2.30    0.39
#
#     5 Day Performance  5 Day Performance  Volume  Lower Circuit  Upper Circuit  VWAP  SMA 30 DMA  50 DMA  150 DMA  200 DMA  Deliverables  P/E  P/B  \
# 0    AVERAGE VOLUME  5-Day  8784613.80  10-Day  277...
# 84   AVERAGE VOLUME  5-Day  1095473.00  10-Day  332...
# 105  AVERAGE VOLUME  5-Day  9783960.40  10-Day  342...
#
#     Unnamed: 8  Unnamed: 9     ...       \
# 0        5-Day   8784613.8     ...
# 84       5-Day   1095473.0     ...
# 105      5-Day   9783960.4     ...
#
# ...

# %%
tab_lst[0]
# Out:
#                                           Company Name         High      Low  \
# 0    Bharti Infratel Add to  Watchlist | Portfolio ...       171.90   156.60
# 1                                                5-Day   8784613.80      NaN
# 2                                               10-Day    277264.40      NaN
# 3                                               30-Day   7688107.13      NaN
# 4                                                3-Day       13.73%      NaN
# 5                                                5-Day       18.01%      NaN
# 6                                                8-Day       19.62%      NaN
# 7    Adani Ports Add to  Watchlist | Portfolio NEWS...       284.50   268.45
# 8                                                5-Day   6101500.40      NaN
# 9                                               10-Day          NaN      NaN
# 10                                              30-Day   5741620.10      NaN
# ...

# %%
# Out:
# [                                          Company Name         High      Low  \
#  0    Bajaj Finance Add to  Watchlist | Portfolio NE...      2131.90  1952.35
#  1                                                5-Day  11507050.20      NaN
#  2                                               10-Day    446407.40      NaN
#  3                                               30-Day   8491278.73      NaN
#  4                                                3-Day       21.63%      NaN
#  5                                                5-Day       18.73%      NaN
#  6                                                8-Day       19.84%      NaN
#  7    M&M Add to  Watchlist | Portfolio NEWS  Pick a...       393.00   358.25
#  8                                                5-Day          NaN      NaN
#  9                                               10-Day          NaN      NaN
#  10                                              30-Day          NaN      NaN
# ...

# %%
# Out:
# [                                          Company Name         High      Low  \
#  0    Bajaj Finance Add to  Watchlist | Portfolio NE...      2131.90  1952.35
#  1                                                5-Day  11507050.20      NaN
#  2                                               10-Day    446407.40      NaN
#  3                                               30-Day   8491278.73      NaN
#  4                                                3-Day       21.63%      NaN
#  5                                                5-Day       18.73%      NaN
#  6                                                8-Day       19.84%      NaN
#  7    M&M Add to  Watchlist | Portfolio NEWS  Pick a...       393.00   358.25
#  8                                                5-Day          NaN      NaN
#  9                                               10-Day          NaN      NaN
#  10                                              30-Day          NaN      NaN
# ...
