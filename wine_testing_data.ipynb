# %%
import re
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import warnings
warnings.filterwarnings('ignore')

url="http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/"

wine_data=pd.read_csv('C://Users//735184//Downloads//winequality-red.csv',sep=';')
wine_data.columns=['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar','chlorides', 'free_sulfur_dioxide', \
                   'total_sulfur_dioxide','density','pH','sulphates', 'alcohol', 'quality']
#
#def mix_to_min(arr):
#    return arr.max()-arr.min()
#wine_grp=wine_data.groupby('quality')
#wine_grp.agg(mix_to_min)
#wine_grp.agg('mean')

wine_data['alcohol/quality_Ratio']=np.round(wine_data['quality']/wine_data['alcohol']*100)
#wine_data.head(4)
#wine_data.pivot_table(index=['quality'])

def ranker(df):
    df['Alc_Ranker']=np.arange(len(df)) +1  #starting from 1 to length of dataframe means without group by it wil be a sequence
    return df

wine_data=wine_data.groupby('quality').apply(ranker)
#wine_data=wine_data.sort_values(['quality'],ascending=False)
a=wine_data[['alcohol','quality','Alc_Ranker']]
a[a.quality ==8]
#bb=a[a.quality ==5]
#bb.sort_values(['Alc_Ranker'],ascending=False)


c=wine_data.quality.value_counts()
c
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
# Out:
#            alcohol  alcohol/quality_Ratio  chlorides  citric_acid   density  \
# quality
# 3         9.955000              30.300000   0.122500     0.171000  0.997464
# 4        10.265094              39.264151   0.090679     0.174151  0.996542
# 5         9.899706              50.848752   0.092736     0.243686  0.997104
# 6        10.629519              57.017241   0.084956     0.273824  0.996615
# 7        11.465913              61.472362   0.076588     0.375176  0.996104
# 8        12.094444              66.777778   0.068444     0.391111  0.995212
#
#          fixed_acidity  free_sulfur_dioxide        pH  residual_sugar  \
# quality
# 3             8.360000            11.000000  3.398000        2.635000
# 4             7.779245            12.264151  3.381509        2.694340
# 5             8.167254            16.983847  3.304949        2.528855
# 6             8.347179            15.711599  3.318072        2.477194
# ...

# %%
a
# Out:
#                          Company_Name     High      Low  Last_Price  \
# 0   Bharti Infratel Add to Watchlist    171.90   156.60       171.1
# 77  Bharti Infratel Add to Watchlist   4796.00  4640.00      4728.0
# 98  Bharti Infratel Add to Watchlist    601.80   592.05       594.8
# 0   Bharti Infratel Add to Watchlist    171.90   156.60       171.1
# 77  Bharti Infratel Add to Watchlist   4796.00  4640.00      4728.0
# 98  Bharti Infratel Add to Watchlist    601.80   592.05       594.8
#
#     Prev_Close  Change
# 0       160.90   10.20
# 77     4692.90   35.10
# 98      591.75    3.05
# 0       160.90   10.20
# 77     4692.90   35.10
# 98      591.75    3.05

# %%
# Out:
#                                           Company Name     High      Low  \
# 0    Bharti Infratel Add to  Watchlist | Portfolio ...   171.90   156.60
# 84   Bajaj Finserv Add to  Watchlist | Portfolio AC...  4796.00  4640.00
# 105  Cipla Add to  Watchlist | Portfolio ACTIONS  P...   601.80   592.05
#
#      Last Price  Prev Close  Change  % Gain  \
# 0        169.20      160.90    8.30    5.16
# 84      4714.95     4692.90   22.05    0.47
# 105      594.05      591.75    2.30    0.39
#
#     5 Day Performance  5 Day Performance  Volume  Lower Circuit  Upper Circuit  VWAP  SMA 30 DMA  50 DMA  150 DMA  200 DMA  Deliverables  P/E  P/B  \
# 0    AVERAGE VOLUME  5-Day  8784613.80  10-Day  277...
# 84   AVERAGE VOLUME  5-Day  1095473.00  10-Day  332...
# 105  AVERAGE VOLUME  5-Day  9783960.40  10-Day  342...
#
#     Unnamed: 8  Unnamed: 9     ...       \
# 0        5-Day   8784613.8     ...
# 84       5-Day   1095473.0     ...
# 105      5-Day   9783960.4     ...
#
# ...

# %%
tab_lst[0]
# Out:
#                                           Company Name         High      Low  \
# 0    Bharti Infratel Add to  Watchlist | Portfolio ...       171.90   156.60
# 1                                                5-Day   8784613.80      NaN
# 2                                               10-Day    277264.40      NaN
# 3                                               30-Day   7688107.13      NaN
# 4                                                3-Day       13.73%      NaN
# 5                                                5-Day       18.01%      NaN
# 6                                                8-Day       19.62%      NaN
# 7    Adani Ports Add to  Watchlist | Portfolio NEWS...       284.50   268.45
# 8                                                5-Day   6101500.40      NaN
# 9                                               10-Day          NaN      NaN
# 10                                              30-Day   5741620.10      NaN
# ...

# %%
# Out:
# [                                          Company Name         High      Low  \
#  0    Bajaj Finance Add to  Watchlist | Portfolio NE...      2131.90  1952.35
#  1                                                5-Day  11507050.20      NaN
#  2                                               10-Day    446407.40      NaN
#  3                                               30-Day   8491278.73      NaN
#  4                                                3-Day       21.63%      NaN
#  5                                                5-Day       18.73%      NaN
#  6                                                8-Day       19.84%      NaN
#  7    M&M Add to  Watchlist | Portfolio NEWS  Pick a...       393.00   358.25
#  8                                                5-Day          NaN      NaN
#  9                                               10-Day          NaN      NaN
#  10                                              30-Day          NaN      NaN
# ...

# %%
# Out:
# [                                          Company Name         High      Low  \
#  0    Bajaj Finance Add to  Watchlist | Portfolio NE...      2131.90  1952.35
#  1                                                5-Day  11507050.20      NaN
#  2                                               10-Day    446407.40      NaN
#  3                                               30-Day   8491278.73      NaN
#  4                                                3-Day       21.63%      NaN
#  5                                                5-Day       18.73%      NaN
#  6                                                8-Day       19.84%      NaN
#  7    M&M Add to  Watchlist | Portfolio NEWS  Pick a...       393.00   358.25
#  8                                                5-Day          NaN      NaN
#  9                                               10-Day          NaN      NaN
#  10                                              30-Day          NaN      NaN
# ...
